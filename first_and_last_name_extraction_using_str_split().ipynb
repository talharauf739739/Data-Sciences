# %%
import pandas as pd

# %%
df = pd.DataFrame({'full_name':['Talha Rauf', 'Asad Abbass', 'Saba Arooj']})
df
# Out:
#      full_name
# 0   Talha Rauf
# 1  Asad Abbass
# 2   Saba Arooj

# %% [markdown]
# Extract fist and last name

# %%
df['first_name'] = df['full_name'].str.split(' ', expand = True)[0]
df['last_name'] = df['full_name'].str.split(' ', expand = True)[1]

df
# Out:
#      full_name first_name last_name
# 0   Talha Rauf      Talha      Rauf
# 1  Asad Abbass       Asad    Abbass
# 2   Saba Arooj       Saba     Arooj
