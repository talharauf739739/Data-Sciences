# %%
import pandas as pd
import numpy as np

# %%
df2 = pd.read_excel('/content/Updated tiktok 14 sep-9oct.txt.xlsx')
df1 = pd.read_csv('/content/podump-2023-10-10.csv')
df2.head()
# Out:
# <ipython-input-12-48bda1d13792>:2: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('/content/podump-2023-10-10.csv')
#        Source     Medium  Transaction ID
# 0  tiktok.com   referral          624994
# 1  tiktok.com   referral          625483
# 2      tiktok   referral          607873
# 3      tiktok   referral          626208
# 4      tiktok  (not set)          597203

# %%
extract_data = df1[df1['Order ID'].isin(df2['Transaction ID'])]
extract_data
# Out:
#        Order ID  Item ID  Flavour ID Product Gift  Product Category  \
# 741      590840     6194       12821          NaN  Wireless Earbuds
# 970      591068     6766       13938          NaN     Smart Watches
# 1794     591877     6203       12853          NaN     Smart Watches
# 1869     591952     6203       14086          NaN     Smart Watches
# 2499     592579     6203       12853          NaN     Smart Watches
# ...         ...      ...         ...          ...               ...
# 36193    626095     6194       12821          NaN  Wireless Earbuds
# 36225    626127     6725       14097          NaN           Mobiles
# 36246    626148     6725       14744          NaN           Mobiles
# 36305    626207     6352       13178          NaN  Wireless Earbuds
# 36306    626208     7040       14695          NaN  Wireless Earbuds
#
#       Product Brand                       Product Title Product Color  \
# 741        Assorted  M10 TWS Wireless Bluetooth Earbuds         black
# ...

# %%
extract_data.to_excel('14Sept_to_9OCT_Tiktok_Data.xlsx', index = False)
